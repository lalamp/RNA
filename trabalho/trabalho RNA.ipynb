# %% [markdown]
# ## **Bibliotecas**

# %%
# API
import requests
import json
import csv

# Manipulação de dados
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# Normalização
from sklearn.preprocessing import MinMaxScaler

# MLP
from sklearn.neural_network import MLPClassifier

# Cross Validation
from sklearn.model_selection import cross_val_predict

# Amostra dos dados
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações do pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## **API Spotify**

# %%
class SpotifyApi:
    def __init__(self):
        # informações da aplicação do spotify
        self._clientId = '9956a83a95c94d72a6c04c7cfa63ec52'
        self._clientSecret = '1a29d0e37da34ffc92a68a5527881a53'

        # token (que expira após um tempo)
        self.accessToken = self.getAccessToken()

    def request(self, url, rType, headers = {}, params = {}):
        '''
        Realiza uma requisição e verifica se deu certo
        '''

        if rType == 'get':
            headers['Authorization'] = 'Bearer ' + str(self.accessToken)
            r = requests.get(url, headers=headers, params=params)
        elif rType == 'post':
            r = requests.post(url, headers=headers, params=params)

        # checa se a requisição deu certo
        rSC = r.status_code
        if rSC >= 200 and rSC < 300:
            return r
        else:
            print('Erro ' + str(r.status_code) + ': ' + r.reason)
            return None

    def uriToId(self, uri):
        '''
        Se necessário, isola e retorna o ID do URI
        '''

        if uri.startswith('spotify'):
            uri = uri.split(':')[-1]
        return uri

    def getAccessToken(self):
        '''
        gera um novo token e o armazena
        '''

        url = 'https://accounts.spotify.com/api/token'

        headers = {'Content-Type': 'application/x-www-form-urlencoded'}
        params = {'grant_type': 'client_credentials', 'client_id': self._clientId, 'client_secret': self._clientSecret}

        r = self.request(url, 'post', headers, params)
        rJson = r.json()

        return rJson['access_token']

    def getPlaylist(self, playlistId, fields = 'id, name, owner(display_name), tracks.items(track(artists(id, name), name, id))'):
        '''
        Retorna dados de uma playlist específica
        '''

        if not fields == '': fields += ', type'

        # codifica fields para funcionar no link
        fields = fields.replace(',', '%2C')
        fields = fields.replace(' ', '+')
        fields = fields.replace('(', '%28')
        fields = fields.replace(')', '%29')

        # pega o ID da playlist
        playlistId = self.uriToId(playlistId)

        # pega os dados da playlist
        url = 'https://api.spotify.com/v1/playlists/' + playlistId + '?fields=' + fields
        r = self.request(url, 'get')

        # checa se deu erro
        if not r:
            print('Playlist dada é privada')
        else:
            return r.json()

    def getTrack(self, trackID):
        '''
        Retorna dados de uma track (música) específica
        '''

        trackId = self.uriToId(trackID)
        url = 'https://api.spotify.com/v1/tracks/' + trackId
        r = self.request(url, 'get')

        if not r:
            print('Música com ID '+ str(trackId) + 'não encontrada')
        else:
            return r.json()

    def getArtist(self, artistId):
        '''
        Retorna dados de um artista específico
        '''

        artistId = self.uriToId(artistId)
        url = 'https://api.spotify.com/v1/artists/' + artistId
        r = self.request(url, 'get')

        if not r:
            print('Artista com ID '+ str(trackId) + 'não encontrada')
        else:
            return r.json()

    def printJson(self, j):
        '''
        Printa o Json
        '''

        jsonStr = json.dumps(j, indent=1)
        print(jsonStr)

    def playlistToCsv(self, p, playlistNum):
        '''
        Printa os dados da playlist e passa para arquivo CSV
        '''

        try:
            if p['type'] != 'playlist':
                print('Objeto não é uma playlist')
                return
        except:
            print('Não foi possível verificar a playlist pelo atributo "type"')
            return

        print('Playlist ' + p['name'])
        print('por ' + p['owner']['display_name'])
        print('-----')

        playlistName = 'playlist' + str(playlistNum) + '.csv'
        with open(playlistName, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile, delimiter=',')
            writer.writerow(['id', 'name', 'popularity', 'release date', 'duration', 'explicit', 'artists', 'genres', 'class'])
            for items in p['tracks']['items']:
                track = items['track']
                data = self.getTrackData(track, playlistNum)
                writer.writerow(data)

    def getTrackData(self, track, num_playlist = 0):
        '''
        Recebe um json de uma track e retorna os seus dados em uma lista
        '''

        trackId = track['id']

        trackName = track['name']
        print(trackName, end=' - ')

        trackDate = track['album']['release_date']
        print(trackDate, end=' - ')

        trackDur = track['duration_ms']
        print(trackDur, end=' - ')

        trackPopularity = track['popularity']
        print(trackPopularity, end=' - ')

        trackExplicit = track['explicit']
        print(trackExplicit, end=' - ')

        artists = track['artists']
        list_artists = []
        list_genres = []
        for i, artist in enumerate(artists):
            artistId = artist['id']
            artistJson = self.getArtist(artistId)
            artistName = artistJson['name']
            artistGenres = artistJson['genres']

            # coloca virgula entre os artistas
            if i == len(artists) - 1: end = '\n'
            else: end = ', '
            print(artistName, end = ' - ')
            print(artistGenres, end = end)

            list_artists.append(artistName)
            list_genres.append(artistGenres)

        mainArtist = list_artists[0]
        mainGenre = list_genres[0]

        data = [trackId, trackName, trackPopularity, trackDate, trackDur, trackExplicit, mainArtist, mainGenre]
        if num_playlist == 1:
            data.append('playlist 1')
        elif num_playlist == 2:
            data.append('playlist 2')
        else:
            data.append('sem playlist')
        return data

# %% [markdown]
# ## **Tratamento de dados**

# %% [markdown]
# ### Gerenciamento dos arquivos CSV
#
# ---

# %%
def writePlaylist(playlistId, playlistNum):
    '''
    Escreve os dados de uma playlist em um arquivo CSV
      playlistId: Id da playlist no spotify
      playlistNum: número da playlist no treinamento, 1 ou 2
    '''

    api = SpotifyApi()

    print("\nPlaylist " + str(playlistNum))

    playlist = api.getPlaylist(playlistId, '')
    api.playlistToCsv(playlist, playlistNum)

# %%
def writeDataBase(playlistId1, playlistId2):
    '''
    Junta as duas playlists em um só aquivo CSV (database.csv)
    '''

    writePlaylist(playlistId1, 1)
    writePlaylist(playlistId2, 2)

    all_filenames = ['playlist1.csv', 'playlist2.csv']

    # combina todos os arquivos da lista
    combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames])

    # exporta para CSV
    combined_csv.to_csv("database.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Processamento dos dados para a Rede Neural
#
# ---

# %%
def prepDataFrame(df):
  '''
  Prepara os dados para o uso na rede neural:
    Retira o id e nome das tracks
    Transforma os dados string para int
  '''

  df = df.drop('id', axis=1)
  df = df.drop('name', axis=1)

  # traduz os dados string para numérico
  for var in ['release date', 'explicit', 'artists', 'genres', 'class']:
      temp = np.array(df[var]).reshape(-1, 1)
      df[var] = enc.fit_transform(temp)

  return df

# %% [markdown]
# Normalização

# %%
def normalizeDataFrame(df):
  '''
  Normaliza os dados
  '''

  features = df.drop(['class'], axis=1)

  scaler = MinMaxScaler()
  norm_data = scaler.fit_transform(features)
  df_norm_data = pd.DataFrame(norm_data)

  df_norm_data['class'] = df['class']

  return df_norm_data

# %% [markdown]
# Processamento total dos dados

# %%
def dataProcessing(df):
  '''
  Prepara o dataframe para o treinamento e processamento
  '''

  df = prepDataFrame(df)
  #print(df)
  return normalizeDataFrame(df)

# %% [markdown]
# ## **MLP**

# %%
class MLP:
    def __init__(self, df, printing = False):
        self.mlp = MLPClassifier(max_iter=1000, solver='adam', hidden_layer_sizes= 106, activation='relu', random_state=1)
        self.df = df
        self.dfNorm = dataProcessing(df)
        self.entries = self.dfNorm.drop(['class'], axis=1)
        self.classes = self.dfNorm['class']
        self.spotifyApi = SpotifyApi()

    def classifier(self, cv_folds=5):
        '''
        Treina e testa a MLP com validação cruzada
        '''

        x = self.entries
        y = self.classes

        # previsões
        predictions = cross_val_predict(self.mlp, x, y, cv=cv_folds)

        # matriz de confusão e métricas
        self.confusionMatrix(predictions)

        # previsões erradas
        self.getWrongResults(predictions)

    def confusionMatrix(self, predictions):
        '''
        Printa a matriz de confusão e métricas do classificador
        '''

        x = self.entries
        y = self.classes

        # matriz de confusão
        matriz_confusao = metrics.confusion_matrix(y, predictions)

        plt.title("Confusion Matrix")
        df_cm = pd.DataFrame(matriz_confusao, range(2), range(2))
        ax = sns.heatmap(df_cm, annot=True, fmt='g', cmap='crest')
        labels = ['playlist 1', 'playlist 2']
        ax.set_xticklabels(labels)
        ax.set_yticklabels(labels)
        plt.xlabel('Predicted')
        plt.ylabel('True')

        # métricas
        print('Métricas:')
        print(metrics.classification_report(y, predictions, target_names=labels))

    def getWrongResults(self, predictions):
        '''
        Printa quais músicas o classificador errou
        '''

        x = self.entries
        y = self.classes

        # index da lista predictions
        predIndex = 0

        #contador
        count = 1

        print('\nErros:')
        # roda por cada item nos dados completos
        for i in y.axes[0]:
            # index do item no database.csv
            dfIndex = i

            # playlist dada pela MLP para o item
            if predictions[predIndex] == 0:
                playlistPred = 'playlist 1'
            else:
                playlistPred = 'playlist 2'

            # iloc devolve a linha com index dfIndex do DataFrame (database.csv)
            track = self.df.iloc[dfIndex]

            # printa os exemplos que classificador errou
            if playlistPred != track['class']:
                print(f'Track {count}')
                count += 1
                print(track)
                playlistTrue = track['class']
                print(f'True: {playlistTrue} \nPredicted: {playlistPred}')
                print()

            # faz o index do predictions acompanhar o index do yTest
            predIndex += 1

# %% [markdown]
# ## **Main**

# %% [markdown]
# ### Criação dos arquivos CSV
# ---
#
# > rodar apenas quando alguma playlist sofrer alteração

# %%
playlist1 = 'spotify:playlist:6O6nD8HLgRsvNRFU1pIYYt'
playlist2 = 'spotify:5joN8srNzN7Pe8qHyThnnv'

writeDataBase(playlist1, playlist2)
# Out:
# Playlist 1
# Playlist so as boa.
# por Lucas
# -----
# Sky Fall - 2014-12-16 - 318093 - 58 - True - Travis Scott - ['hip hop', 'rap', 'slap house'], Young Thug - ['atl hip hop', 'atl trap', 'gangster rap', 'melodic rap', 
Ryu, the Runner - ['detroit trap brasileiro', 'trap brasileiro'], Luk The Real - [], Emitê Único - [], 6ee - [], Salve Crazy - []
# Business - 2023-03-03 - 132923 - 64 - True - Ryu, the Runner - ['detroit trap brasileiro', 'trap brasileiro'], Gu$Z - [], Salve Crazy - []
# Praise The Lord (Da Shine) (feat. Skepta) - 2018-05-25 - 205040 - 84 - True - A$AP Rocky - ['east coast hip hop', 'hip hop', 'rap', 'trap'], Skepta - ['birmingham grime', 'grime', 'instrumental grime', 'uk hip hop']
#
# Playlist 2
# Playlist :)
# por Larissa
# -----
# Before You Go - 2019-11-19 - 215106 - 75 - False - Lewis Capaldi - ['pop', 'uk pop']
# Someone You Loved - 2019-05-17 - 182160 - 90 - False - Lewis Capaldi - ['pop', 'uk pop']
# Andar Sozinho (feat. Jão) - 2019-06-14 - 180213 - 59 - False - Lagum - ['belo horizonte indie', 'nova mpb'], Jão - ['pop nacional']
# Samba - 2018-05-04 - 160238 - 59 - False - Lagum - ['belo horizonte indie', 'nova mpb']
# Falando a Verdade - 2019-06-14 - 153600 - 48 - False - Lagum - ['belo horizonte indie', 'nova mpb']
# Coisa da Geração - 2019-06-14 - 174440 - 43 - False - Lagum - ['belo horizonte indie', 'nova mpb']
# Falling - 2019-12-13 - 240133 - 84 - False - Harry Styles - ['pop']
# Wake Me Up - Radio Edit - 2013-01-01 - 247426 - 39 - False - Avicii - ['dance pop', 'edm', 'pop', 'pop dance']
# Hey, Soul Sister - 2018-11-23 - 216653 - 44 - False - Train - ['dance pop', 'neo mellow', 'pop', 'pop rock']
# This Town - 2017-10-20 - 232852 - 83 - False - Niall Horan - ['pop']
# Flicker - 2017-10-20 - 258025 - 64 - False - Niall Horan - ['pop']
# Seeing Blind - 2017-10-20 - 185280 - 64 - False - Niall Horan - ['pop'], Maren Morris - ['classic texas country', 'contemporary country']
# Detesto Despedidas - 2019-06-14 - 174720 - 59 - False - Lagum - ['belo horizonte indie', 'nova mpb']
# History - 2015-11-13 - 187426 - 75 - False - One Direction - ['boy band', 'pop', 'post-teen pop', 'talent show']
# Saturday Sun - 2018-02-23 - 214720 - 75 - False - Vance Joy - ['folk-pop', 'modern rock']
# Monster (Shawn Mendes & Justin Bieber) - 2020-11-20 - 178994 - 71 - False - Shawn Mendes - ['canadian pop', 'pop', 'viral pop'], Justin Bieber - ['canadian pop', 'pop']
# Ho Hey - 2012 - 163133 - 82 - False - The Lumineers - ['folk-pop', 'modern rock', 'stomp and holler']
# Pierre - 2015-08-28 - 202733 - 59 - False - Ryn Weaver - ['electropop', 'indie poptimism']
# Glad You Came - 2011-01-01 - 197935 - 80 - False - The Wanted - ['boy band', 'dance pop', 'pop', 'post-teen pop']
# On My Own - 2015-01-01 - 145413 - 66 - False - Ross Lynch - ['post-teen pop']
# You & I - 2013-11-25 - 237933 - 78 - False - One Direction - ['boy band', 'pop', 'post-teen pop', 'talent show']
# Amiga Da Minha Mulher - 2011-01-01 - 248080 - 0 - False - Seu Jorge - ['mpb', 'samba-rock']
# Burguesinha - 2007-01-01 - 258186 - 0 - False - Seu Jorge - ['mpb', 'samba-rock']
# The Nights - 2014-01-01 - 176658 - 87 - False - Avicii - ['dance pop', 'edm', 'pop', 'pop dance']
# Coastline (feat. Hollow Coves) - 2017-10-13 - 182520 - 55 - False - Liu - ['brazilian edm'], WOAK - ['brazilian edm', 'brazilian house'], Hollow Coves - ['indie anthem-folk', 'indie folk', 'modern indie folk']
# Free Spirit - 2019-04-05 - 182080 - 60 - False - Khalid - ['pop', 'pop r&b']
# Empire State Of Mind - 2009-09-08 - 276920 - 85 - True - JAY-Z - ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'r
- False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# Yellow - 2000-07-10 - 266773 - 91 - False - Coldplay - ['permanent wave', 'pop']
# Story of My Life - 2013-11-25 - 245493 - 85 - False - One Direction - ['boy band', 'pop', 'post-teen pop', 'talent show']
# I'm Yours - 2008-05-01 - 242946 - 79 - False - Jason Mraz - ['acoustic pop', 'dance pop', 'neo mellow', 'pop']
# The Scientist - 2002-08-08 - 309600 - 87 - False - Coldplay - ['permanent wave', 'pop']
# A Vida É Boa Com Você - Voz E Violão - 2020-07-01 - 170409 - 59 - False - Bryan Behr - ['musica catarinense', 'nova mpb']
# Tá Vendo Aquela Lua - 2011-07-05 - 196306 - 69 - False - Exaltasamba - ['axe', 'pagode', 'pagode novo', 'samba paulista', 'sertanejo universitario']
# Deixa Acontecer - 2009-07-01 - 246226 - 66 - False - Grupo Revelação - ['pagode', 'pagode novo']
# Use Somebody / Otherside - Ao Vivo - 2012-04-16 - 223266 - 39 - False - Oba Oba Samba House - ['pagode novo']
# There's Nothing Holdin' Me Back - 2017-04-20 - 199440 - 88 - False - Shawn Mendes - ['canadian pop', 'pop', 'viral pop']
# Chasing Cars - 2006-01-01 - 267960 - 83 - False - Snow Patrol - ['irish rock', 'modern rock', 'neo mellow', 'permanent wave', 'pop rock']
# 18 - 2014-11-17 - 248360 - 82 - False - One Direction - ['boy band', 'pop', 'post-teen pop', 'talent show']
# The A Team - 2011-09-09 - 258373 - 76 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# Lego House - 2011-09-09 - 185093 - 75 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# drivers license - 2021-05-21 - 242013 - 87 - True - Olivia Rodrigo - ['pop']
# Perfect - 2017-03-03 - 263400 - 89 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# Photograph - 2014-06-21 - 258986 - 86 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# Paradise - 2011-10-24 - 278719 - 86 - False - Coldplay - ['permanent wave', 'pop']
# Another Love - 2013-06-24 - 244360 - 92 - True - Tom Odell - ['chill pop']
# Marry You - 2010-10-05 - 230192 - 81 - False - Bruno Mars - ['dance pop', 'pop']
# Say You Won't Let Go - 2016-10-28 - 211466 - 88 - False - James Arthur - ['pop', 'talent show', 'uk pop']
# Rude - 2014-06-25 - 224840 - 83 - False - MAGIC! - ['pop', 'reggae fusion']
# Castle on the Hill - 2017-03-03 - 261153 - 81 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# Waves - 2019-03-22 - 240013 - 77 - False - Dean Lewis - ['australian pop', 'pop']
# Clocks - 2002-08-08 - 307879 - 84 - False - Coldplay - ['permanent wave', 'pop']
# Wonder - 2020-12-07 - 172692 - 49 - False - Shawn Mendes - ['canadian pop', 'pop', 'viral pop']
# Look Up At The Stars - 2020-12-07 - 211850 - 42 - False - Shawn Mendes - ['canadian pop', 'pop', 'viral pop']
# Supermarket Flowers - 2017-03-03 - 221106 - 77 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']
# Bruises - 2019-05-17 - 220492 - 83 - False - Lewis Capaldi - ['pop', 'uk pop']
# Ophelia - 2016-04-08 - 160097 - 82 - False - The Lumineers - ['folk-pop', 'modern rock', 'stomp and holler']
# Be Alright - 2019-03-22 - 196493 - 81 - True - Dean Lewis - ['australian pop', 'pop']
# Don't You Worry Child - Radio Edit - 2012-09-14 - 212862 - 84 - False - Swedish House Mafia - ['edm', 'pop dance', 'progressive electro house'], John Martin - ['pop edm']
# País do Futebol - 2013-03-11 - 149002 - 58 - False - MC Guime - ['brazilian hip hop', 'funk carioca', 'funk ostentacao'], Emicida - ['afrofuturismo brasileiro', 'brazilian hip hop', 'brazilian reggae', 'funk ostentacao', 'hip hop tuga', 'manguebeat', 'pop lgbtq+ brasileira']
# Fire On Fire - 2020-10-30 - 246735 - 79 - False - Sam Smith - ['pop', 'uk pop']
# Matilda - 2022-05-20 - 245964 - 82 - False - Harry Styles - ['pop']
# Mona Lisa (Spider-Man: Across the Spider-Verse) - 2023-06-02 - 186066 - 75 - False - Dominic Fike - ['alternative pop rock', 'pov: indie']
# Sunflower - Spider-Man: Into the Spider-Verse - 2018-12-14 - 158040 - 86 - False - Post Malone - ['dfw rap', 'melodic rap', 'pop', 'rap'], Swae Lee - ['melodic rap', 'rap', 'trap']
# Pompeii - 2014-05-09 - 235433 - 45 - False - Jason Goodman - ['fake']
# I Lived - 2013-01-01 - 234546 - 76 - False - OneRepublic - ['piano rock', 'pop']
# Budapest - 2014-06-27 - 200720 - 1 - False - George Ezra - ['folk-pop', 'neo-singer-songwriter', 'talent show']
# Party In The U.S.A. - 2009-01-01 - 202066 - 84 - False - Miley Cyrus - ['pop']
# Waiting For Love - 2015-10-02 - 230613 - 83 - False - Avicii - ['dance pop', 'edm', 'pop', 'pop dance']
# Hey Brother - 2013-01-01 - 255093 - 80 - False - Avicii - ['dance pop', 'edm', 'pop', 'pop dance']
# Billie Bossa Nova - 2021-07-30 - 196730 - 80 - False - Billie Eilish - ['art pop', 'pop']
# ocean eyes - 2017-12-22 - 200379 - 84 - False - Billie Eilish - ['art pop', 'pop']
# Love Love - 2019 - 205984 - 71 - False - Gilsons - ['nova mpb']
# Algum Ritmo - 2021-04-09 - 215383 - 64 - False - Gilsons - ['nova mpb'], Jovem Dionisio - ['indie curitibano']
# Brother - 2018-09-28 - 203186 - 76 - False - Kodaline - ['irish pop', 'modern rock', 'neo mellow']
# Hey There Delilah - 2005-01-01 - 232533 - 80 - False - Plain White T's - ['modern rock', 'neo mellow', 'neon pop punk', 'pop punk', 'pop rock']
# I'm Not The Only One - 2014-05-26 - 239316 - 86 - False - Sam Smith - ['pop', 'uk pop']
# Too Good At Goodbyes - 2017-11-03 - 201000 - 87 - False - Sam Smith - ['pop', 'uk pop']
# Stay With Me - 2014-05-26 - 172723 - 86 - False - Sam Smith - ['pop', 'uk pop']
# Never Be Alone - 2015-04-14 - 215813 - 67 - False - Shawn Mendes - ['canadian pop', 'pop', 'viral pop']
# Happier - 2017-03-03 - 207520 - 80 - False - Ed Sheeran - ['pop', 'singer-songwriter pop', 'uk pop']

# %% [markdown]
# ### MLP
# ---

# %%
df = pd.read_csv('database.csv')
mlp = MLP(df)
mlp.classifier()
# Out:
# A execução de células com 'c:\Users\lal4mp\AppData\Local\Programs\Python\Python310\python.exe' requer o pacote ipykernel.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/lal4mp/AppData/Local/Programs/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'
